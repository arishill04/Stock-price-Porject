# %%
import yfinance as yf
import matplotlib.pyplot as plt
import datetime
import mplfinance as mpf

# %%
end = datetime.datetime.today()
days_back = int(input("Number of Days "))
enddelt = datetime.timedelta(days=days_back)
start = end - enddelt
stock_name = str(input("Stock Ticker Symbol "))


data = yf.download(stock_name, start, end)
data['Date'] = data.index
data = data[["Date", "Open", "High", "Low", "Close", "Adj Close", "Volume"]]
data.set_index("Date")

data
# Out:
# Number of Days 100
# Stock Ticker Symbol AAPL
# [*********************100%***********************]  1 of 1 completed
#                  Date        Open        High         Low       Close  \
# Date
# 2022-10-26 2022-10-26  150.960007  151.990005  148.039993  149.350006
# 2022-10-27 2022-10-27  148.070007  149.050003  144.130005  144.800003
# 2022-10-28 2022-10-28  148.199997  157.500000  147.820007  155.740005
# 2022-10-31 2022-10-31  153.160004  154.240005  151.919998  153.339996
# 2022-11-01 2022-11-01  155.080002  155.449997  149.130005  150.649994
# ...               ...         ...         ...         ...         ...
# 2023-01-27 2023-01-27  143.160004  147.229996  143.080002  145.929993
# 2023-01-30 2023-01-30  144.960007  145.550003  142.850006  143.000000
# 2023-01-31 2023-01-31  142.699997  144.339996  142.279999  144.289993
# 2023-02-01 2023-02-01  143.970001  146.610001  141.320007  145.429993
# 2023-02-02 2023-02-02  148.899994  151.179993  148.169998  150.820007
#
#              Adj Close     Volume
# Date
# 2022-10-26  149.102661   88194300
# 2022-10-27  144.560196  109180200
# 2022-10-28  155.482086  164762400
# 2022-10-31  153.086044   97943200
# 2022-11-01  150.400497   80379300
# ...                ...        ...
# 2023-01-27  145.929993   70492800
# 2023-01-30  143.000000   64015300
# 2023-01-31  144.289993   65874500
# 2023-02-01  145.429993   77663600
# 2023-02-02  150.820007  118338980
#
# [68 rows x 7 columns]

# %%
close = data["Close"].plot(figsize=(15, 10))

mpf.plot(data,type='candle',volume =True)
